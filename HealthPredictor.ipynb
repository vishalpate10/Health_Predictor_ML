# %%
# Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
import pickle

# %%
# Step 1: Load dataset
df = pd.read_csv('health_predictor_dataset.csv')

# %%
df
# Out:
#     Height_cm  Weight_kg   BMI       Status
# 0         188         75  21.2      Healthy
# 1         178         89  28.1          Fat
# 2         164         79  29.4          Fat
# 3         157         43  17.4  Underweight
# 4         170         41  14.2  Underweight
# 5         188         45  12.7  Underweight
# 6         168         93  33.0          Fat
# 7         172         81  27.4          Fat
# 8         160         43  16.8  Underweight
# 9         160         93  36.3          Fat
# 10        173         68  22.7      Healthy
# 11        185         57  16.7  Underweight
# 12        189         65  18.2  Underweight
# 13        173         83  27.7          Fat
# 14        152         73  31.6          Fat
# 15        171         49  16.8  Underweight
# 16        151         75  32.9          Fat
# 17        173         53  17.7  Underweight
# 18        179         70  21.8      Healthy
# 19        187         87  24.9      Healthy
# ...

# %%
# Step 2: Feature selection
X = df[['Height_cm', 'Weight_kg']]
y = df['Status']

# %%
# Encode target labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)  # 0 = Fat, 1 = Healthy, 2 = Underweight

# %%
# Step 3: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# --- KNN Model ---
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)

# %%
print(accuracy_score(y_test, knn_pred))
print(classification_report(y_test, knn_pred, target_names=le.classes_))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          Fat       1.00      1.00      1.00         6
#      Healthy       1.00      1.00      1.00         3
#  Underweight       1.00      1.00      1.00         1
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %%
# Save model
with open("HealthPredictor.pkl", "wb") as f:
    pickle.dump(knn, f)

print("✅ Model saved as 'HealthPredictor.pkl'")
# Out:
# ✅ Model saved as 'HealthPredictor.pkl'
